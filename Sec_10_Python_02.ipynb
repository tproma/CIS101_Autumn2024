# %%
number = 5

if number % 2 == 0:
  print("Even")
else:
  print("Odd")
# Out:
# Odd

# %%
n = -5
if n<0:
  print("Negative")
elif n==0:
  print("neutral")
else:
  print("Positive")
# Out:
# Negative

# %%
print('''Proma
djkfgkdgf
sjdfjsdgfkg''')
# Out:
# Proma
# djkfgkdgf
# sjdfjsdgfkg

# %%
# comment
a = 5  # variable declare
print(a)
# Out:
# 5

# %%
print("a")
# Out:
# a

# %%
a = 4
b = 34
c = 55

print("a = ", a)
print("b -> ", b)
print("c >>> ", c)

print("a = ", a, "; b: ", b)
# Out:
# a =  4
# b ->  34
# c >>>  55
# a =  4 ; b:  34

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
a = "Hello"
b = "World"
c = " ! "
print("a = ", a)
print("b : ", b)
print("c : ", c)

print(a, b,c)
# Out:
# a =  Hello
# b :  World
# c :   !
# Hello World  !

# %%
print(type(a))
# Out:
# <class 'str'>

# %%
a = input("Enter a value: ")
print("The value is " , a)
# Out:
# Enter a value: 56
# The value is  56

# %%
a = int(input("Enter a : "))
b = input("Enter b : ")

c = int(a) - int(b)
print(c)


f = float(a) * float(b)
print(f)
# Out:
# Enter a : 5
# Enter b : 2
# 3
# 10.0

# %%
a = input("Enter a : ")
b = input("Enter b : ")

c = int(a) // int(b)
print(c)
# Out:
# Enter a : 66
# Enter b : 4
# 16

# %%
x = int(input())
y = int(input())

z = x+y
print(z)
# Out:
# 5
# 6
# 11

# %%
a = 66//4
print(a)
# Out:
# 16

# %%
a, b, c = 34, "hdjgfjhdg", 3.3
print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
name = " Proma"
id = "1736427643"
c_id = "cis101"
print("Student Name : ", name, "\tID: ", id, "\nCourse Id: ", c_id)
# Out:
# Student Name :   Proma 	ID:  1736427643
# Course Id:  cis101

# %%
x = input("Enter x: ")
y = input()

z = int(x) + int(y)
print(f'The sum is {z}')
# Out:
# Enter x: 6
# 4
# The sum is 10

# %%
a = 5
b = 3
c = a ** b # exponent
print(c)
# Out:
# 125

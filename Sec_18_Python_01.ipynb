# %%
print("Hellodjfhgldhfgjdf;jg;l")
print('world')
# Out:
# Hellodjfhgldhfgjdf;jg;l
# world

# %%
print('''klsdhkjhskjdg
skdjfgkjsdhlj kfdjgkjh   kfdjgkjh
ksjdgfkg''')
# Out:
# klsdhkjhskjdg
# skdjfgkjsdhlj kfdjgkjh   kfdjgkjh
# ksjdgfkg

# %%
# basic print
a = 5 # kfjghkjdfhkjgh
b = "proma"
print(a)
print(b)
print("a ==" , a, "\nName ->", b)
# Out:
# 5
# proma
# a == 5
# Name -> proma

# %%
a, b, c = 34, "hdjgfjhdg", 3.3
print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
x = int(input("Enter x:"))
y = int(input())

z = x+y
print(z)
# Out:
# Enter x:5
# 3
# 8

# %%
name = "Tanjina Proma"
id = "1736427643"
c_id = "cis101"
print("Student Name:", name, "\tID:", id, "\nCourse Id:", c_id)
# Out:
# Student Name:  Proma 	ID: 1736427643
# Course Id: cis101

# %%
x = input("Enter x: ")
y = input()

z = int(x) + int(y)
print(f'The sum is {z}')
# Out:
# Enter x: 5
# 6
# The sum is 11

# %%
a = 5
b = 3
c = a ** b
print(c)
# Out:
# 125

# %%
a = 66
b = 4

z = a//b
print(z)
# Out:
# 16
